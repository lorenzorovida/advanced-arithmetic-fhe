# %%
import random
import numpy as np

# %%
def dec(bits):
    return sum(int(bit) << i for i, bit in enumerate(np.round(bits, decimals=2)))

def tobin(x, size):
    x_bin = bin(x)[2:].zfill(size)
    x_bin = [int(bit) for bit in reversed(x_bin)]
    
    return np.array(x_bin)

# %%
def koggestone(a, b, size = 2):
    n = size

    P = mod2shallow(np.add(a, b))
    G = np.multiply(a, b)
    
    Pcopy = P.copy()
    
    step = 1
    
    while step < n:   
        G = G + P * np.roll(G, step)
        P = P * np.roll(P, step)
           
        step *= 2

    carry = np.roll(G, 1)
    
    S = (np.subtract(Pcopy, carry) ** 2)
    
    return S

# %%
def mod2shallow(x):
    return -x**2+2*x

# %%
for bits in [8, 16, 32, 64, 128, 256]:
    x = random.randrange(2**bits)
    y = random.randrange(2**bits)

    print("{}-bits".format(bits))
    print("Expected: {}".format(x + y))
    print("Obtained: {}".format(dec(koggestone(tobin(x, bits*(bits // 2)), tobin(y, bits*(bits // 2)), bits))))
    print("*********")
# Out:
# 8-bits
# Expected: 169
# Obtained: 169
# *********
# 16-bits
# Expected: 52617
# Obtained: 52617
# *********
# 32-bits
# Expected: 4650853232
# Obtained: 4650853232
# *********
# 64-bits
# Expected: 27646223942285671984
# Obtained: 27646223942285671984
# *********
# 128-bits
# Expected: 471843541566269794486790633424247939337
# Obtained: 471843541566269794486790633424247939337
# *********
# 256-bits
# Expected: 189633057871960811736924861871008777720498736030085480816857837896709740423670
# Obtained: 189633057871960811736924861871008777720498736030085480816857837896709740423670
# *********

# %% [markdown]
# ## Subtraction

# %%
def koggestone_withcarry(a, b, size = 2):
    n = size

    bbar = b           
    P = mod2shallow(np.add(a, bbar))
    G = np.multiply(a, bbar)  
    G[size] += 1
    
    Pcopy = P.copy()

    step = 1
    while step < n:
        G = G + P * np.roll(G, step)
        P = P * np.roll(P, step)
        step *= 2

    carry = np.roll(G + P, 1)           

    S = (np.subtract(Pcopy, carry) ** 2)
    return S

# %%
def koggestone_withcarry(a, b, size = 2):
    n = size
      
    P = mod2shallow(np.add(a, b))
    G = np.multiply(a, b)  
    G[-1] = 1
    
    Pcopy = P.copy()

    step = 1
    while step < n:
        G = G + P * np.roll(G, step)
        P = P * np.roll(P, step)
        step *= 2

    carry = np.roll(G, 1)           

    S = (np.subtract(Pcopy, carry) ** 2)
    return S

# %%
for bits in [8, 16, 32, 64, 128, 256]:
    x = random.randrange(2**bits)
    y = random.randrange(2**bits)
    
    biny = tobin(y, bits*(bits // 2))
    mask = np.zeros(bits * bits // 2)
    mask[:bits] = 1
    biny = mask - biny
    

    print("{}-bits".format(bits))
    print("Expected: {}".format((x - y) % 2**bits))
    print("Obtained: {}".format(dec(koggestone_withcarry(tobin(x, bits*(bits // 2)), biny, bits)) % 2**bits))
    print("*********")
# Out:
# 8-bits
# Expected: 49
# Obtained: 49
# *********
# 16-bits
# Expected: 38802
# Obtained: 38802
# *********
# 32-bits
# Expected: 3135482953
# Obtained: 3135482953
# *********
# 64-bits
# Expected: 5566561623008921188
# Obtained: 5566561623008921188
# *********
# 128-bits
# Expected: 24695841080043303169008944563715153794
# Obtained: 24695841080043303169008944563715153794
# *********
# 256-bits
# Expected: 38510300704051343925305815322167108930033030874755924192239537865986233483746
# Obtained: 38510300704051343925305815322167108930033030874755924192239537865986233483746
# *********
