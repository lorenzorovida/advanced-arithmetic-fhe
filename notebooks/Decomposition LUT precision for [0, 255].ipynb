# %% [markdown]
# Using degree 401

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from random import randrange

class Chebyshev:
    """
    Chebyshev(a, b, n, func)
    Given a function func, lower and upper limits of the interval [a,b],
    and maximum degree n, this class computes a Chebyshev approximation
    of the function.
    Method eval(x) yields the approximated function value.
    """
    def __init__(self, a, b, n, func):
        n = n + 1
        self.a = a
        self.b = b
        self.func = func

        bma = 0.5 * (b - a)
        bpa = 0.5 * (b + a)
        f = [func(math.cos(math.pi * (k + 0.5) / n) * bma + bpa) for k in range(n)]
        self.roots = f

        self.x = [math.cos(math.pi * (k + 0.5) / n) * bma + bpa for k in range(n)]

        fac = 2.0 / n
        self.c = [fac * sum([f[k] * math.cos(math.pi * j * (k + 0.5) / n)
                  for k in range(n)]) for j in range(n)]

    def eval(self, x):
        a,b = self.a, self.b
        #assert(a <= x <= b)
        y = (2.0 * x - a - b) * (1.0 / (b - a))
        y2 = 2.0 * y
        (d, dd) = (self.c[-1], 0)             # Special case first step for efficiency
        for cj in self.c[-2:0:-1]:            # Clenshaw's recurrence
            (d, dd) = (y2 * d - dd + cj, d)
        return y * d - dd + 0.5 * self.c[0]   # Last step is different

# %%
def mod_reduction(bit_position):
    period = 2**bit_position
    
    assert period % 2 == 0 and period >= 2
    P = period
    seq = np.array([0]*(P//2) + [1]*(P//2), dtype=float)

    c = np.fft.fft(seq) / P

    def f(x):
        s = c[0].real
        for k in range(1, P//2):
            ck = c[k]
            ang = 2 * math.pi * k * x / P
            s += 2 * (ck.real * math.cos(ang) - ck.imag * math.sin(ang))

        s += c[P//2].real * math.cos(math.pi * x)
        return s
    
    return f

# %%
a=0
b=255

p1 = Chebyshev(a, b, 441, mod_reduction(1))           # Period 2 {0, 1}
p2 = Chebyshev(a, b, 441, mod_reduction(2))           # Period 4 {0, 0, 1, 1}
p3 = Chebyshev(a, b, 441, mod_reduction(3))           # Period 8 {0, 0, 0, 0, 1, 1, 1, 1}
p4 = Chebyshev(a, b, 441, mod_reduction(4))           # Period 16 
p5 = Chebyshev(a, b, 441, mod_reduction(5))           # Period 32
p6 = Chebyshev(a, b, 441, mod_reduction(6))           # Period 64
p7 = Chebyshev(a, b, 441, mod_reduction(7))           # Period 128
p8 = Chebyshev(a, b, 441, mod_reduction(8))           # Period 256

# %%
# Set it to true if you need to export the coefficients

if False:
    with open("p1-451.txt", "w") as f:
        f.write(",".join(str(x) for x in p1.c))
    with open("p2-451.txt", "w") as f:
        f.write(",".join(str(x) for x in p2.c))
    with open("p3-451.txt", "w") as f:
        f.write(",".join(str(x) for x in p3.c))
    with open("p4-451.txt", "w") as f:
        f.write(",".join(str(x) for x in p4.c))
    with open("p5-451.txt", "w") as f:
        f.write(",".join(str(x) for x in p5.c))
    with open("p6-451.txt", "w") as f:
        f.write(",".join(str(x) for x in p6.c))
    with open("p7-451.txt", "w") as f:
        f.write(",".join(str(x) for x in p7.c))
    with open("p8-451.txt", "w") as f:
        f.write(",".join(str(x) for x in p8.c))

# %%
x = np.arange(a, b, 0.01)

plt.plot(x, np.vectorize(mod_reduction(1))(x))
plt.plot(x, np.vectorize(p1.eval)(x))

print("Error for p1: {}".format(max(abs(np.vectorize(mod_reduction(1))(x) - np.vectorize(p1.eval)(x)))))
# Out:
# Error for p1: 1.2455787173903943e-07

# %%
x = np.arange(a, b, 0.001)

plt.plot(x, np.vectorize(mod_reduction(2))(x))
plt.plot(x, np.vectorize(p2.eval)(x))

print("Error for p2: {}".format(max(abs(np.vectorize(mod_reduction(2))(x) - np.vectorize(p2.eval)(x)))))
# Out:
# Error for p2: 8.992806499463768e-14

# %%
x = np.arange(a, b, 0.001)

plt.plot(x, np.vectorize(mod_reduction(3))(x))
plt.plot(x, np.vectorize(p3.eval)(x))

print("Error for p1: {}".format(max(abs(np.vectorize(mod_reduction(3))(x) - np.vectorize(p3.eval)(x)))))
# Out:
# Error for p1: 1.0774714453987144e-13

# %%
x = np.arange(a, b, 0.001)

plt.plot(x, np.vectorize(mod_reduction(4))(x))
plt.plot(x, np.vectorize(p4.eval)(x))

print("Error for p4: {}".format(max(abs(np.vectorize(mod_reduction(4))(x) - np.vectorize(p4.eval)(x)))))
# Out:
# Error for p4: 9.084399898995343e-14

# %%
x = np.arange(a, b, 0.001)

plt.plot(x, np.vectorize(mod_reduction(5))(x))
plt.plot(x, np.vectorize(p5.eval)(x))

print("Error for p5: {}".format(max(abs(np.vectorize(mod_reduction(5))(x) - np.vectorize(p5.eval)(x)))))
# Out:
# Error for p5: 7.524536549396998e-14

# %%
x = np.arange(a, b, 0.001)

plt.plot(x, np.vectorize(mod_reduction(6))(x))
plt.plot(x, np.vectorize(p6.eval)(x))

print("Error for p6: {}".format(max(abs(np.vectorize(mod_reduction(6))(x) - np.vectorize(p6.eval)(x)))))
# Out:
# Error for p6: 1.1558462520433466e-11

# %%
x = np.arange(a, b, 0.001)

plt.plot(x, np.vectorize(mod_reduction(7))(x))
plt.plot(x, np.vectorize(p7.eval)(x))

print("Error for p7: {}".format(max(abs(np.vectorize(mod_reduction(7))(x) - np.vectorize(p7.eval)(x)))))
# Out:
# Error for p7: 1.6866907870394243e-10

# %%
x = np.arange(a, b, 0.001)

plt.plot(x, np.vectorize(mod_reduction(8))(x))
plt.plot(x, np.vectorize(p8.eval)(x))

print("Error for p8: {}".format(max(abs(np.vectorize(mod_reduction(8))(x) - np.vectorize(p8.eval)(x)))))
# Out:
# Error for p8: 4.3358789302005984e-10
